# %% [markdown]
# Use 3C263 as example here.  It has non-SDSS wavelength resolution, high S2N, and coverage at 2500Å, so it be a good object for solely testing the rebin implementation.

# %%
from astropy.io import fits
import sys
sys.path.append("/Users/Trevor1/Dropbox/ICA_module/code_main/")
#sys.path.append("/Users/Trevor1/Dropbox/ICA_module/")
import run_ICA_r20_components
sys.path.append("/Users/Trevor1/Dropbox/HST/HSTCode/")
import Cut_Edge_Pix_TVM
import Small_Pix_Filter_TVM
import spec_morph
import plot_ICA
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import weightedstats as ws
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
def arg2min(arr):
    #return index of second closest point
    return np.argsort(arr)[1]

# %%
spec_path = "/Users/Trevor1/Dropbox/HST/Sulentic_spectra/SulenticAllData/FOS/3C263/"

# %%
dat1 = pd.read_csv(spec_path+"NecessaryParams.csv")

# %%
dat1
# Out:
#   filters     obs_id
# 0   G190H  y0pe0902t
# 1   G270H  y0pe0903t
# 2   G400H  y0pe0904t
# 3   G190H  y0rv1h03t
# 4   G270H  y0rv1h04t

# %%
# !ls -l /Users/Trevor1/Dropbox/HST/Sulentic_spectra/SulenticAllData/FOS/3C263/y0pe0902t
# Out:
# total 544
# -rwxr--r--@ 1 Trevor1  staff  66240 Feb  2  2015 y0pe0902t_c0f.fits
# -rwxr--r--@ 1 Trevor1  staff  66240 Feb  2  2015 y0pe0902t_c1f.fits
# -rwxr--r--@ 1 Trevor1  staff  66240 Feb  2  2015 y0pe0902t_c2f.fits
# -rwxr--r--@ 1 Trevor1  staff  66240 Feb  2  2015 y0pe0902t_cqf.fits

# %%
z = 0.6465

wave = np.flip(fits.open(spec_path+'y0pe0903t/y0pe0903t_c0f.fits')[0].data[0,:]) #/ (1+z)
flux = np.flip(fits.open(spec_path+'y0pe0903t/y0pe0903t_c1f.fits')[0].data[0,:])
errs = np.flip(fits.open(spec_path+'y0pe0903t/y0pe0903t_c2f.fits')[0].data[0,:])
mask = np.flip(fits.open(spec_path+'y0pe0903t/y0pe0903t_cqf.fits')[0].data[0,:])

# %%
plt.plot(wave, flux)
plt.ylim(0,None)
# Out:
# (0.0, 1.618445698300746e-14)

# %%
[print(wave[i+1]-wave[i]) for i in range(len(wave)-1)]
# Out:
# 0.5144043
# 0.5144043
# 0.5144043
# 0.5144043
# 0.5144043
# 0.5144043
# 0.5144043
# 0.5144043
# 0.5144043
# 0.5144043
# 0.51416016
# 0.5144043
# 0.5144043
# 0.5144043
# 0.51416016
# 0.5144043
# 0.5144043
# 0.51416016
# 0.5144043
# 0.5144043
# 0.51416016
# 0.5144043
# 0.51416016
# 0.5144043
# 0.51416016
# 0.5144043
# 0.51416016
# 0.5144043
# 0.51416016
# 0.51416016
# 0.5144043
# 0.51416016
# 0.51416016
# 0.5144043
# 0.51416016
# 0.51416016
# 0.51416016
# 0.5144043
# 0.51416016
# 0.51416016
# 0.51416016
# 0.51416016
# 0.51416016
# 0.51416016
# 0.51416016
# 0.51416016
# 0.51416016
# 0.51416016
# 0.51416016
# 0.51416016
# 0.51416016
# 0.51416016
# 0.51416016
# 0.513916
# 0.51416016
# 0.51416016
# 0.51416016
# 0.513916
# 0.51416016
# 0.51416016
# 0.513916
# 0.51416016
# 0.51416016
# 0.513916
# 0.51416016
# 0.513916
# 0.51416016
# 0.513916
# 0.51416016
# 0.513916
# 0.51416016
# 0.513916
# 0.51416016
# 0.513916
# 0.513916
# 0.51416016
# 0.513916
# 0.513916
# 0.51416016
# 0.513916
# ...

# %%
resolution = [3.e5*((wave[i+1]-wave[i])/wave[i]) for i in range(len(wave)-1)]
resolution
# Out:
# [69.44261403987184,
#  69.42654435988516,
#  69.41047904547304,
#  69.39442246221006,
#  69.37837461009622,
#  69.36233548913151,
#  69.34630073374137,
#  69.33027470950037,
#  69.31425741640851,
#  69.29824448889121,
#  69.24935878487304,
#  69.26625355845317,
#  69.25026245880872,
#  69.23428445588797,
#  69.18545550433919,
#  69.20235027791932,
#  69.18638973729685,
#  69.13760880706832,
#  69.15449921507388,
#  69.13856050232425,
#  69.08982759341598,
#  69.10671800142154,
#  69.05801128596067,
#  69.07490169396624,
#  69.02622553752735,
#  69.04311594553292,
#  68.99446598254144,
#  69.01135639054701,
#  68.96274135215208,
#  68.94688995089382,
#  68.96378035889938,
#  68.91520461067557,
#  68.89937940286472,
#  68.91626544529572,
#  68.86773771839216,
#  68.85193433845416,
#  68.83613532409072,
#  68.85302136652172,
#  68.80455039208755,
#  68.78877320559695,
#  68.7730047502555,
#  68.75724502606317,
#  68.74148966744542,
#  68.7257430399768,
#  68.71000077808276,
# ...

# %%
np.median(resolution) #in km/s
# Out:
# 55.694398179184645

# %% [markdown]
# So the pixel spacing for HST is constant in wavelength space, but not velocity space.  I wonder if there's any way that we can leverage that.

# %%
hdulist = fits.open('/Users/Trevor1/Dropbox/HST/ICA/spec-0266-51630-0080.fits')
sdss_c0 = hdulist[0].header['coeff0'] #central loglam of first pixel
sdss_c1 = hdulist[0].header['coeff1'] #loglam spacing between pixels
sdss_npix = hdulist[1].header['NAXIS2']
sdss_loglam = sdss_c0 + sdss_c1 * np.arange(sdss_npix)
sdss_wave = 10.**(sdss_loglam)

# %%
sdss_wave
# Out:
# array([3796.64507922, 3797.51938971, 3798.39390155, ..., 9132.71699665,
#        9134.82012457, 9136.92373681])

# %%
logwave = np.log10(wave)

# %%
logwave_rebin_start = np.log10(wave[0])
logwave_rebin_end   = np.log10(wave[-1])

# %%
logwave_rebin_start, logwave_rebin_end
# Out:
# (3.3467999, 3.5155072)

# %%
np.arange(logwave_rebin_start, logwave_rebin_end, 0.0001)
# Out:
# array([3.34679985, 3.34689985, 3.34699985, ..., 3.51529985, 3.51539985,
#        3.51549985])

# %%
loglam_rebin = np.arange(logwave_rebin_start, logwave_rebin_end, 0.0001)

# %%
loglam_rebin_edges = loglam_rebin - 0.0001/2
loglam_rebin_edges = np.append(loglam_rebin_edges, loglam_rebin[-1]+0.0001/2)

# %%
fig = plt.figure(figsize=(16,3))
plt.scatter(loglam_rebin, len(loglam_rebin)*[0], label="SDSS pixels")
plt.scatter(loglam_rebin_edges, len(loglam_rebin_edges)*[0], marker="|", s=500, color="r", label="SDSS pixel edges")
plt.scatter(np.log10(wave), len(wave)*[0.0015])
plt.xlim(3.3465, 3.35)
#plt.xlim(3.346+0.1, 3.35+0.1)
plt.ylim(-0.001,0.011)
plt.legend(loc="upper left")
plt.show()

# %%
flux_rebin = np.nan*np.zeros(len(loglam_rebin))
errs_rebin = np.nan*np.zeros(len(loglam_rebin))
mask_rebin = np.zeros(len(loglam_rebin))
flux_rebin
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
for i in range(len(loglam_rebin_edges)-1):
    ledge_rebin, redge_rebin = loglam_rebin_edges[i], loglam_rebin_edges[i+1]
    #orig edges
    #oldwidth = 
    
    maskOrig = (logwave>ledge_rebin)&(logwave<redge_rebin)
    if not maskOrig.sum()==0:
        #flux_rebin[i] = ws.numpy_weighted_median(flux[maskOrig], weights=1./(errs[maskOrig]**2))
        flux_rebin[i] = np.median(flux[maskOrig])
        errs_rebin[i] = np.median(errs[maskOrig])
        mask_rebin[i] = np.max(mask[maskOrig])
    
if (np.isnan(flux_rebin)).any():
    #initial resolution could be low enough such that some re-binned pixels weren't assigned a value
    #for those, interpolate with nearest neighbors
    for j in range(len(flux_rebin)):
        if np.isnan(flux_rebin[j]):
            arg1 = np.argmin(loglam_rebin[~np.isnan(flux_rebin)]-loglam[j])
            arg2 = arg2min(loglam_rebin[~np.isnan(flux_rebin)]-loglam[j])
            loglam1, flux1, errs1 = loglam_rebin[~np.isnan(flux_rebin)][arg1], \
                                    flux_rebin[~np.isnan(flux_rebin)][arg1], \
                                    errs_rebin[~np.isnan(flux_rebin)][arg1]
            loglam2, flux2, errs2 = loglam_rebin[~np.isnan(flux_rebin)][arg2], \
                                    flux_rebin[~np.isnan(flux_rebin)][arg2], \
                                    errs_rebin[~np.isnan(flux_rebin)][arg2]
            oldwidth = abs(loglam2-loglam1)
            #do linear fit on nearest non-nan neighbors
            m_flux, b_flux = np.polyfit([loglam1, loglam2], [flux1, flux2], 1)
            flux_rebin[j] = m_flux*loglam_rebin[j] + b_flux
            m_errs, b_errs = np.polyfit([loglam1, loglam2], [errs1, errs2], 1)
            errs_rebin[j] = (m_errs*loglam_rebin[j] + b_errs) * np.sqrt(oldwidth/0.0001)
            #leave mask[j]==0 for now
            
wave_rebin = 10.**loglam_rebin

# %%
plt.plot(wave, flux, alpha=0.7)
plt.plot(wave_rebin, flux_rebin, alpha=0.7)
plt.plot(wave, errs, color="grey", alpha=0.5)
plt.plot(wave_rebin, errs_rebin, color="grey")

plt.scatter(wave[mask>0], flux[mask>0], color="b", zorder=3)
plt.scatter(wave_rebin[mask_rebin>0], flux_rebin[mask_rebin>0], color="r", zorder=3)

#plt.xlim(1500*(1+z),1600*(1+z))
plt.ylim(0,None)
# Out:
# (0.0, 1.618445698300746e-14)

# %% [markdown]
# Implemented above to ICA code - see if it works!

# %% [raw]
# flux_arb, errs_arb, wave_ica, flux_ica, f2500_ica = run_ICA_r20_components.main_ICA(wave/(1+z), flux, errs,
#                                                                           mask, z, name="",
#                                         ica_path="/Users/Trevor1/Dropbox/ICA_module/components/")

# %%
wave_arb, flux_arb, errs_arb, mask_arb, wave_ica, flux_ica = run_ICA_r20_components.main_ICA(wave/(1+z), flux, errs, 
                                                                          mask, z, name="", 
                                                   ica_path="/Users/Trevor1/Dropbox/ICA_module/components/")
# Out:
# Input wavelength resolution does not match 69 km/s.  Re-binning spectrum.

# %%
plot_ICA.spec_wreconstruction(wave_arb, flux_arb, errs_arb, mask_arb, wave_ica, flux_ica)

# %%
fig = plt.figure(figsize=(15,7))
plt.plot(wave_arb, flux_arb)
plt.plot(wave_ica, flux_ica)
plt.show()

# %%
fig = plt.figure(figsize=(15,7))
plt.plot(wave_arb, flux_arb)
plt.plot(wave_ica, flux_ica)
plt.xlim(1400,1750)
plt.show()
